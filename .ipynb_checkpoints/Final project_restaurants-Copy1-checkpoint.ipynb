# %%
import pandas as pd
import numpy as np
import plotly.figure_factory as ff
from plotly.offline import iplot

import plotly.express as px
from plotly.subplots import make_subplots

import plotly.graph_objects as go
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Analyzing Dataframe

# %%
# Reading dataframe 
df = pd.read_csv('restaurants.csv')
df.head()
# Out:
#                              Name  \
# 0                           Local
# 1                   The G.T. ROAD
# 2                         Tamasha
# 3               The Junkyard Cafe
# 4  Chili's American Grill and Bar
#
#                                        Location        Locality   City  \
# 0  Scindia House,Connaught Place, Central Delhi   Central Delhi  Delhi
# 1        M-Block,Connaught Place, Central Delhi   Central Delhi  Delhi
# 2                Connaught Place, Central Delhi   Central Delhi  Delhi
# 3                Connaught Place, Central Delhi   Central Delhi  Delhi
# 4        M-Block,Connaught Place, Central Delhi   Central Delhi  Delhi
#
#                                              Cuisine  Rating  Votes  Cost
# 0           North Indian,  Finger Food,  Continental     4.1   2415  2000
# 1                                       North Indian     4.3   2363  1500
# 2  Finger Food,  North Indian,  Italian,  Contine...     4.2   5016  2000
# 3  North Indian,  Mediterranean,  Asian,  Italian...     4.2   2821  1800
# 4                       Mexican,  American,  Italian     4.4   1094  2000

# %%
# Evaluating dataframe
print('* Size of dataframe: {}\n'.format(df.shape))
print('* Datatype of columns are:\n {}\n'.format(df.info()))
# Out:
# * Size of dataframe: (6593, 8)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6593 entries, 0 to 6592
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6593 non-null   object
#  1   Location  6593 non-null   object
#  2   Locality  6593 non-null   object
#  3   City      6593 non-null   object
#  4   Cuisine   6593 non-null   object
#  5   Rating    6593 non-null   float64
#  6   Votes     6593 non-null   int64
#  7   Cost      6593 non-null   int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 412.2+ KB
# * Datatype of columns are:
#  None

# %%
df.describe()
# Out:
#             Rating        Votes         Cost
# count  6593.000000  6593.000000  6593.000000
# mean      4.088200   119.420143  1102.798271
# std       0.670031   261.849704   716.935212
# min       1.000000     1.000000   100.000000
# 25%       3.900000     6.000000   500.000000
# 50%       4.200000    31.000000   900.000000
# 75%       4.400000   115.000000  1500.000000
# max       5.000000  5016.000000  8000.000000

# %%
df['City'].value_counts()
# Out:
# Bangalore     1019
# Delhi          734
# Mumbai         727
# Kolkata        712
# Hyderabad      589
# Ahmedabad      414
# Chennai        388
# Pune           351
# Jaipur         268
# Chandigarh     264
# Indore         204
# Gurgaon        184
# Noida          146
# Vadodara        91
# Lucknow         80
# Agra            75
# Nagpur          66
# Surat           64
# Ludhiana        62
# Goa             60
# Ghaziabad       50
# Udaipur         43
# Kochi            2
# Name: City, dtype: int64

# %% [markdown]
# Cities can be categorized in terms of State.

# %% [markdown]
# Adding State Column

# %%
df['State'] = df['City']
df['State'] = df['City'].replace({'Bangalore': 'Karnataka', 'Delhi':'Delhi NCR', 'Mumbai':'Maharashtra', 'Kolkata':'Bengal', 'Hyderabad':'Telangana', 'Ahmedabad':'Gujarat', 'Chennai':'Tamil Nadu', 'Pune':'Maharashtra', 'Jaipur':'Rajasthan', 'Chandigarh':'Punjab', 'Indore':'Madhya Pradesh', 'Gurgaon':'Delhi NCR', 'Noida':'Delhi NCR', 'Vadodara':'Gujarat', 'Lucknow':'Uttar Pradesh', 'Agra':'Uttar Pradesh', 'Nagpur':'Maharashtra', 'Surat':'Gujarat', 'Ludhiana':'Punjab', 'Goa':'Goa', 'Ghaziabad':'Delhi NCR', 'Udaipur':'Rajasthan', 'Kochi':'Kerala'})
df['State'].value_counts()
# Out:
# Maharashtra       1144
# Delhi NCR         1114
# Karnataka         1019
# Bengal             712
# Telangana          589
# Gujarat            569
# Tamil Nadu         388
# Punjab             326
# Rajasthan          311
# Madhya Pradesh     204
# Uttar Pradesh      155
# Goa                 60
# Kerala               2
# Name: State, dtype: int64

# %% [markdown]
# Kochi has just two restaurants.

# %% [markdown]
# Removing Kochi

# %%
kochi_df = df[df['City']=='Kochi']
kochi_df.index
df = df.drop(kochi_df.index)
df['City'].value_counts()
# Out:
# Bangalore     1019
# Delhi          734
# Mumbai         727
# Kolkata        712
# Hyderabad      589
# Ahmedabad      414
# Chennai        388
# Pune           351
# Jaipur         268
# Chandigarh     264
# Indore         204
# Gurgaon        184
# Noida          146
# Vadodara        91
# Lucknow         80
# Agra            75
# Nagpur          66
# Surat           64
# Ludhiana        62
# Goa             60
# Ghaziabad       50
# Udaipur         43
# Name: City, dtype: int64

# %% [markdown]
# Distribution of restaurant ratings, cost and votes in India

# %%
fig = ff.create_distplot([df.Rating],['Rating'],bin_size = 0.1)
fig.update_layout(title_text = 'Distribution of Restaurant Ratings')
# Out:
# <div>                            <div id="9b6efbb2-8b91-40e3-b2bd-702b08b72ead" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b6efbb2-8b91-40e3-b2bd-702b08b72ead")) {                    Plotly.newPlot(                        "9b6efbb2-8b91-40e3-b2bd-702b08b72ead",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"Rating","marker":{"color":"rgb(31, 119, 180)"},"name":"Rating","opacity":0.7,"x":[4.1,4.3,4.2,4.2,4.4,3.9,4.0,4.3,3.9,4.2,4.1,4.1,4.2,4.1,4.3,4.0,4.2,4.2,4.2,4.2,4.2,4.1,4.1,4.2,4.5,3.5,4.2,4.4,4.4,4.4,4.1,4.4,4.2,4.5,4.2,3.9,4.1,3.9,4.2,4.3,4.2,4.1,4.5,4.1,4.1,4.3,4.4,4.3,4.1,3.8,3.8,4.0,4.1,4.0,4.0,4.1,4.1,4.2,4.0,4.2,3.9,4.1,4.4,3.8,4.4,4.2,4.1,4.2,4.2,4.2,4.0,4.3,5.0,4.8,4.4,4.5,4.3,4.1,3.7,4.6,4.1,4.4,3.7,2.9,5.0,3.0,4.5,3.8,4.5,4.2,4.4,4.4,3.9,4.4,4.1,4.2,4.3,4.2,4.0,4.2,4.5,3.8,4.5,4.1,4.5,4.3,4.2,4.0,4.1,4.3,4.4,4.3,4.2,4.5,3.9,5.0,4.3,4.4,4.2,4.5,4.3,4.7,4.1,4.3,4.1,4.0,4.4,4.2,3.6,4.0,4.1,3.8,3.9,4.2,5.0,4.1,4.4,4.2,4.4,4.4,4.3,4.3,4.5,3.1,4.3,4.0,4.2,4.6,3.6,5.0,4.2,4.3,4.4,4.3,4.0,4.3,4.4,4.2,3.9,3.6,4.3,3.9,4.1,4.1,4.2,4.5,4.4,4.2,4.2,4.1,4.4,4.3,4.1,4.4,4.5,4.5,3.7,4.3,3.7,4.7,4.7,4.4,4.2,3.7,4.3,4.2,4.1,4.2,4.2,4.5,4.1,4.2,4.1,4.0,4.4,4.1,4.7,5.0,4.1,4.4,4.3,3.5,4.5,3.3,4.5,4.2,4.4,4.3,4.2,4.3,4.4,3.7,4.0,4.5,4.1,4.3,4.6,4.2,4.0,4.4,3.9,4.5,4.0,4.5,4.5,4.2,3.4,4.1,3.8,4.2,4.8,4.3,5.0,4.4,3.8,3.8,4.2,4.2,5.0,4.4,3.9,4.2,4.4,4.0,4.0,4.9,4.5,4.2,4.4,4.1,4.4,3.7,4.2,5.0,4.1,4.0,4.5,4.0,4.0,4.5,3.9,4.0,4.1,4.5,4.1,5.0,4.4,3.6,4.4,3.6,4.3,4.4,4.0,4.3,4.5,3.6,3.0,4.3,4.1,3.1,4.8,3.0,4.1,4.5,3.9,4.3,4.3,4.2,3.9,3.1,5.0,3.8,4.4,4.1,4.1,4.1,4.5,4.2,4.4,4.2,4.4,4.4,3.3,4.2,3.8,3.6,4.4,4.4,4.1,4.5,4.0,4.2,4.1,5.0,4.3,4.1,4.0,4.1,4.3,4.4,3.7,4.2,4.1,5.0,4.4,4.3,4.7,4.3,4.5,4.3,4.0,4.3,4.3,4.4,4.2,4.2,4.6,4.0,4.1,4.5,4.5,4.6,3.7,4.6,4.1,2.0,4.1,4.3,4.5,4.6,4.0,4.0,4.1,4.3,4.5,3.8,4.8,4.0,4.1,4.5,4.2,3.5,5.0,3.9,4.2,4.3,3.8,3.9,4.5,3.4,4.5,4.1,4.0,3.5,4.3,3.3,5.0,4.4,4.2,4.2,3.5,5.0,4.2,4.5,4.2,4.3,4.5,4.2,4.6,4.3,4.4,4.3,5.0,4.4,4.0,4.1,4.3,4.1,4.1,4.4,4.4,4.7,4.5,4.6,1.0,4.3,4.6,4.2,4.0,4.5,5.0,4.4,4.3,4.2,4.5,4.2,4.3,4.2,4.4,4.2,4.0,3.9,3.9,4.3,3.2,3.9,4.2,4.3,4.2,2.3,4.6,4.8,4.0,5.0,5.0,3.8,4.4,5.0,4.3,4.5,3.8,4.4,4.2,4.4,4.3,4.1,4.3,4.0,4.3,4.5,4.9,4.1,5.0,3.9,4.1,4.2,4.5,4.3,4.3,4.0,2.0,4.1,4.3,4.1,3.9,4.4,4.2,4.5,4.4,4.5,3.9,4.8,4.0,4.5,4.0,4.5,4.6,4.4,4.1,4.1,4.1,4.6,4.2,4.3,5.0,4.3,3.5,4.1,4.0,4.5,3.6,4.4,4.3,4.1,4.0,3.8,3.7,4.4,4.2,5.0,4.4,4.0,1.0,4.3,5.0,3.4,4.2,4.2,4.4,3.9,4.1,4.3,4.3,4.2,1.0,4.3,4.2,3.8,4.3,5.0,3.0,4.0,5.0,4.4,4.0,4.2,4.4,4.5,4.6,4.1,4.2,3.3,4.6,4.5,4.5,3.3,5.0,4.4,4.3,4.0,4.2,4.3,4.0,4.1,4.2,4.4,4.2,5.0,4.1,4.5,4.2,4.3,4.3,4.0,3.9,3.9,4.3,4.7,4.4,4.2,4.4,4.4,4.3,4.4,4.4,4.3,4.8,4.3,4.4,4.5,3.9,4.3,4.3,4.3,4.6,4.2,4.4,4.1,3.5,4.6,4.2,3.0,4.0,4.2,4.1,4.2,3.9,4.2,4.3,4.1,4.5,3.6,4.4,4.5,4.5,4.1,4.4,4.3,4.2,3.0,4.4,4.0,4.5,4.6,3.5,4.0,4.2,4.5,4.5,4.2,3.4,5.0,4.3,4.6,4.3,4.2,3.0,3.7,5.0,3.5,3.9,3.7,4.2,4.3,1.0,4.3,4.4,4.1,4.2,4.5,4.0,4.3,4.6,4.2,5.0,4.3,4.4,4.6,4.2,4.1,4.3,3.5,3.6,4.0,4.2,4.4,4.2,4.2,4.1,4.3,4.4,4.0,4.4,3.0,4.2,4.4,4.1,4.1,4.3,4.3,4.4,4.2,4.2,4.5,4.5,4.3,4.5,4.3,4.1,4.1,3.4,3.7,4.6,4.1,3.8,4.1,4.0,4.4,2.9,4.7,3.9,3.0,4.1,3.5,3.9,4.0,3.4,4.5,4.8,4.1,4.1,4.0,4.3,5.0,4.2,4.5,3.0,4.2,4.2,3.8,4.0,4.0,4.1,4.1,3.8,4.6,4.2,4.2,4.1,4.3,4.0,3.7,3.9,4.3,4.4,3.7,4.2,4.3,4.3,4.0,3.9,5.0,5.0,4.4,4.5,4.4,4.4,4.3,4.3,3.5,4.2,5.0,4.8,2.7,3.9,4.3,4.1,4.2,4.3,4.0,1.0,4.3,4.5,4.2,5.0,4.6,4.3,4.4,3.9,4.2,4.3,3.6,4.3,4.3,4.0,4.1,3.9,3.5,3.9,5.0,4.1,3.4,4.5,4.2,5.0,5.0,5.0,4.2,4.4,4.3,4.3,4.5,4.0,4.3,4.1,4.3,4.4,4.3,5.0,4.3,4.5,4.5,4.3,4.4,4.1,4.5,4.4,5.0,4.4,4.4,4.2,4.0,4.1,4.4,3.9,5.0,4.5,4.5,3.7,4.5,4.3,4.4,4.5,4.5,3.9,4.5,4.4,1.0,3.6,3.5,3.7,3.4,1.0,4.2,5.0,4.4,4.2,4.5,4.2,4.4,4.5,4.2,4.3,4.4,4.3,4.0,3.6,2.1,4.1,4.5,4 ...

# %%
fig = ff.create_distplot([df.Cost],['Cost'], bin_size = 100)
fig.update_layout(title_text='Distribution of Restaurant Cost')
# Out:
# <div>                            <div id="35471c56-d19d-4643-b116-1229f7b51a02" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35471c56-d19d-4643-b116-1229f7b51a02")) {                    Plotly.newPlot(                        "35471c56-d19d-4643-b116-1229f7b51a02",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"Cost","marker":{"color":"rgb(31, 119, 180)"},"name":"Cost","opacity":0.7,"x":[2000,1500,2000,1800,2000,2000,1800,2100,1500,1000,2000,2500,700,2000,1700,2100,1500,2000,2200,2000,2600,2000,2000,2000,2000,2000,2000,4000,2000,2800,2400,2000,1400,2000,2200,1800,2000,1200,2500,1200,1200,1500,1000,2200,2000,1500,1700,1000,800,1800,500,1200,2200,2100,1800,1200,2000,2000,500,2500,2500,1800,2200,1800,800,2800,2200,1200,500,3000,1000,500,1200,500,2500,4000,800,400,2800,4000,2700,4000,2200,1200,500,400,1500,500,1500,1800,2500,2000,1200,1200,1400,1000,1200,1600,500,2600,600,800,800,1500,2500,500,1600,1200,2000,2200,1800,1000,1500,1200,1500,800,2200,3500,800,5000,1000,4000,2000,1500,2200,2000,2600,1200,1500,2500,1100,800,900,3000,400,1500,1200,1500,3000,2100,1000,4000,1900,1000,2500,800,1600,900,1000,500,2000,2000,2200,1700,3000,1500,1200,1500,1200,1000,2100,1700,1300,800,1800,500,1200,1000,2000,2200,900,2100,1800,2000,2000,2000,700,1800,800,400,500,1500,1600,1000,1200,2000,1800,800,1200,800,1200,2000,1600,1500,1400,2800,800,400,2000,5000,700,400,5000,400,2000,1600,1700,1300,3000,1000,800,300,2400,4500,800,5000,800,1500,600,700,1500,1000,2500,2000,2000,2000,1500,1100,2200,1800,1500,1600,500,2000,1500,1200,1600,800,1500,700,800,1700,800,700,400,600,4500,2200,1200,1800,1200,1000,2300,1200,800,1000,4000,800,1200,400,800,2200,1600,1800,1500,300,2500,700,4000,500,400,1500,1600,3000,500,1000,400,2200,1000,1000,2000,300,2500,500,1000,2000,1800,1600,1000,1200,800,1500,2500,1500,400,2400,1000,4000,1200,1200,2000,2000,1600,2000,4500,400,2000,900,1600,2000,600,1700,1800,1000,1000,1000,400,400,2000,500,400,500,1400,400,1800,600,2500,3000,1600,2000,2100,1800,400,2400,1200,2300,500,1200,1300,1700,1000,800,1000,1000,2200,700,1500,2000,3000,4500,600,1400,1000,3000,1500,1500,3000,1500,1300,1700,1600,700,500,1200,2400,2200,1000,1800,1300,700,500,2300,1800,1700,1500,500,1000,900,3600,1500,1800,400,1500,1200,1700,1100,500,1800,2500,900,1400,3600,1200,2000,400,600,1300,400,1700,800,2000,700,1000,500,800,400,500,2000,900,1000,500,2100,400,1000,800,3500,1500,400,1500,1800,900,2000,1500,2000,2000,1500,2200,1800,2800,600,3000,1400,2000,1500,600,600,1500,500,500,2000,800,3200,500,2000,500,1200,1800,1000,1000,1400,2000,900,400,1400,1400,1100,1500,1300,1200,1500,500,1700,2000,1000,800,2000,3000,5000,1600,1700,2200,800,2000,700,800,2400,1500,2000,900,700,2500,2100,1100,2000,400,2000,600,2000,1300,1200,1500,2000,1800,2100,1000,1800,900,2000,4000,400,1200,400,500,500,400,800,1000,2800,2200,800,1300,1000,1200,2000,500,3000,1000,600,2000,800,700,600,500,600,1200,1500,3200,1700,2500,1200,1000,2700,500,3700,1500,2000,400,2000,1200,2400,2000,2200,1000,2000,2000,2000,1600,700,900,1800,1200,1000,1700,800,2200,700,2300,900,400,2000,1800,1700,500,1500,500,1300,2000,500,3000,1800,1500,400,300,2200,800,1000,500,1200,2200,900,2000,800,1600,1500,1200,3000,500,2000,1200,1500,1400,800,2000,1500,400,500,1500,1000,2000,1000,1000,500,400,1200,1000,1700,2600,3000,500,900,1500,400,700,1700,2600,1600,1500,1400,500,1800,1100,400,1500,3500,400,1000,1400,500,1800,2700,2000,2000,6000,2000,500,1500,1200,1000,2000,1800,2000,1200,700,2000,1200,800,1000,4400,2400,900,1600,1600,1500,400,2200,800,500,900,2100,1600,3000,1500,500,3000,2700,800,2500,2800,1100,1500,600,600,600,2500,400,2300,800,3000,900,1200,1500,600,3000,500,1200,1800,400,2200,1000,3000,1900,3100,2000,800,2300,1700,900,1400,2200,1000,900,2000,3500,1500 ...

# %%
fig = ff.create_distplot([df.Votes], ['Votes'], bin_size = 200)
fig.update_layout(title_text='Distribution of Restaurant Votes')
# Out:
# <div>                            <div id="7e28fe9b-aba5-47d1-984d-3239a6fb7a5e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e28fe9b-aba5-47d1-984d-3239a6fb7a5e")) {                    Plotly.newPlot(                        "7e28fe9b-aba5-47d1-984d-3239a6fb7a5e",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"Votes","marker":{"color":"rgb(31, 119, 180)"},"name":"Votes","opacity":0.7,"x":[2415,2363,5016,2821,1094,1391,1022,963,506,712,2428,2335,223,1817,1301,1501,134,1410,1272,2694,845,297,1624,388,416,101,1753,491,776,500,1634,4265,1534,826,881,310,1269,1098,117,712,50,2503,335,922,38,1378,610,167,181,110,54,3270,147,65,180,69,91,92,37,75,574,158,69,263,9,276,43,187,68,146,417,66,1,9,23,113,46,169,193,152,318,310,23,20,2,2,576,19,25,499,415,123,3055,90,1076,443,447,2118,51,615,2,401,190,82,146,453,614,37,634,646,11,851,555,1482,1296,1,85,532,55,306,431,3,25,120,156,1652,1275,83,51,40,570,426,12,40,1,2422,643,2062,165,306,340,203,899,8,291,12,510,58,7,1,1629,1479,481,434,22,2548,108,939,622,13,2478,1294,350,17,283,125,1082,1157,482,844,58,1372,622,451,1046,1157,81,1435,227,3,5,470,383,75,553,624,234,1363,221,3,1008,681,570,1,54,1832,51,1,239,25,268,12,84,38,809,569,477,387,1071,257,403,8,561,67,161,27,120,390,22,100,116,120,58,1251,215,815,56,21,431,916,79,336,1,741,176,278,59,155,4,18,142,95,391,43,2,17,55,370,312,193,69,67,750,2,2243,408,36,33,359,6,30,42,945,116,205,1,323,76,464,44,31,232,176,947,4,8,14,86,19,8,9,2,2399,175,20,724,619,1229,20,9,1,399,165,41,7,816,23,77,207,257,275,1789,88,919,8,40,223,20,2696,1202,2,415,88,1,103,57,27,220,479,22,3,328,214,1,550,4,38,388,222,652,169,608,3,319,280,1333,5,80,16,506,2,7,13,3,62,3,106,489,897,89,13,7,11,192,141,129,10,343,55,518,131,20,2,186,476,266,14,258,8,5,185,190,90,29,121,3,2,62,159,232,140,1,143,229,173,54,2,330,133,203,14,147,2,111,1,40,198,37,42,118,576,42,103,3,1,12,213,423,44,107,4,398,5,435,18,35,257,22,367,925,41,70,137,8,7,986,546,97,551,3,799,22,48,1,1,15,379,4,30,266,50,260,59,529,289,393,367,223,245,18,6,346,2,398,22,79,113,413,33,179,2,61,884,251,42,1479,704,708,556,888,77,11,1,2,8,402,11,239,80,104,10,8,15,86,3,628,17,355,32,170,22,155,265,89,1,77,12,217,312,1,9,1,2,67,1,4,204,143,799,48,385,99,34,99,1,201,25,7,264,5,1,1,1,26,41,219,240,427,62,88,6,40,5,504,630,8,1,73,375,1403,23,423,7,86,550,120,221,13,68,73,306,3,129,5,391,83,144,21,2,194,442,870,27,117,82,691,26,34,80,337,524,69,16,225,37,45,19,74,33,85,122,1,281,259,591,759,14,340,504,251,451,4,400,209,42,85,461,66,104,12,122,1,60,85,63,173,335,155,24,68,9,1,127,328,357,327,1,908,1,13,8,23,69,558,1,524,583,10,173,192,261,138,302,308,6,274,59,6,241,99,503,14,12,219,17,271,57,79,102,9,116,165,14,4,612,34,54,7,77,23,122,399,28,268,103,83,70,132,54,28,17,60,13,215,25,192,163,100,7,77,31,24,60,2,99,22,33,35,4,37,402,141,414,2,969,385,2,251,244,20,1,305,11,169,131,518,10,263,161,22,3,70,847,50,310,88,575,6,355,381,27,1,13,15,967,306,440,35,409,455,156,1,4,10,29,416,1014,211,16,1,1,14,18,883,1,7,181,36,10,331,241,7,29,481,2,212,19,57,531,1,216,23,16,158,1,7,3,324,59,514,99,26,127,126,54,408,31,87,1,70,1080,216,19,11,29,380,204,2,124,4,494,43,43,10,64,1,259,6,51,36,54,128,2,168,9,98,144,1,8,40,6,19,1,158,1,763,351,87,17,819,736,72,382,705,286,51,49,7,69,226,122,1,1344,4,34,22,111,17,9,152,514,240,2,58,109,217,44,10,349,46,32,175,470,12,158,221,209,34,315,15,69,80,18,11,130,315,94,223,33,173,231,243,145,286,344,287,45,3,715,97,683,548,253,130,36,184,372,4,140,40,7,201,640,27,581,111,238,226,394,217,314,5,137,13,475,40,78,516,8,26,506,911,47,10,220,222,24,13,505,211,494,1,2,64,1,145,8,1342,63,448,1,1,59,1,260,196,196,1,694,8,4,494,329,464,295,187,55,62,151,6,118,138,44,11,4,676,48,42,200,1,326,30,371,155,71,306,176,29,391,2,5,14,72,7,64 ...

# %% [markdown]
# The above distribution do not provide analysis in terms of states or cities. The region-wise restaurant performance is evaluated in following sections.

# %% [markdown]
# Inference 1: How are restaurants distributed across India?

# %%
# Forming dataframes in term of cities and state
city_restaurants = df.groupby('City').sum()
state_restaurants = df.groupby('State').sum()

# List of states
rest_states = df['State'].value_counts()
rest_states
# Out:
# Maharashtra       1144
# Delhi NCR         1114
# Karnataka         1019
# Bengal             712
# Telangana          589
# Gujarat            569
# Tamil Nadu         388
# Punjab             326
# Rajasthan          311
# Madhya Pradesh     204
# Uttar Pradesh      155
# Goa                 60
# Name: State, dtype: int64

# %%
fig = px.bar(x = rest_states.index, y = rest_states)
fig.update_layout(xaxis_title = 'States', yaxis_title = 'Total Restaurants', 
                  title_text = 'Restaurant Distribution Across States', 
                  title_x = 0.5)
fig.show()
# Out:
# <div>                            <div id="bd60c68d-5de8-4f0c-b261-e81980abe29d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd60c68d-5de8-4f0c-b261-e81980abe29d")) {                    Plotly.newPlot(                        "bd60c68d-5de8-4f0c-b261-e81980abe29d",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Maharashtra","Delhi NCR","Karnataka","Bengal","Telangana","Gujarat","Tamil Nadu","Punjab","Rajasthan","Madhya Pradesh","Uttar Pradesh","Goa"],"xaxis":"x","y":[1144,1114,1019,712,589,569,388,326,311,204,155,60],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"t ...

# %%
restnt_city = df['City'].value_counts().sort_values(ascending = True) 

fig = px.bar(y = restnt_city.index, x=restnt_city, color=restnt_city, orientation = 'h',
            labels = {
                'color': 'Total' +'<br>'+ 'Restaurants'
            }) # color continuous scale
fig.update_layout(yaxis_title = 'States', xaxis_title = 'Total Restaurants', 
                  title_text='Restaurant Distribution Across Cities', 
                  title_x=0.5,
                  font=dict(
                      family="Courier New, monospace",
                      size=12,
                      color='rgb(12, 128, 128)'
                  )
                  )
fig.show()
# Out:
# <div>                            <div id="3c7c323b-b68a-4b0a-baff-7f38d2417a40" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c7c323b-b68a-4b0a-baff-7f38d2417a40")) {                    Plotly.newPlot(                        "3c7c323b-b68a-4b0a-baff-7f38d2417a40",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<br>Total<br>Restaurants=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[43,50,60,62,64,66,75,80,91,146,184,204,264,268,351,388,414,589,712,727,734,1019],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[43,50,60,62,64,66,75,80,91,146,184,204,264,268,351,388,414,589,712,727,734,1019],"xaxis":"x","y":["Udaipur","Ghaziabad","Goa","Ludhiana","Surat","Nagpur","Agra","Lucknow","Vadodara","Noida","Gurgaon","Indore","Chandigarh","Jaipur","Pune","Chennai","Ahmedabad","Hyderabad","Kolkata","Mumbai","Delhi","Bangalore"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"ou ...

# %% [markdown]
# Inference 2: How are average ratings distributed across India?

# %%
df.head()
# Out:
#                              Name  \
# 0                           Local
# 1                   The G.T. ROAD
# 2                         Tamasha
# 3               The Junkyard Cafe
# 4  Chili's American Grill and Bar
#
#                                        Location        Locality   City  \
# 0  Scindia House,Connaught Place, Central Delhi   Central Delhi  Delhi
# 1        M-Block,Connaught Place, Central Delhi   Central Delhi  Delhi
# 2                Connaught Place, Central Delhi   Central Delhi  Delhi
# 3                Connaught Place, Central Delhi   Central Delhi  Delhi
# 4        M-Block,Connaught Place, Central Delhi   Central Delhi  Delhi
#
#                                              Cuisine  Rating  Votes  Cost  \
# 0           North Indian,  Finger Food,  Continental     4.1   2415  2000
# 1                                       North Indian     4.3   2363  1500
# 2  Finger Food,  North Indian,  Italian,  Contine...     4.2   5016  2000
# 3  North Indian,  Mediterranean,  Asian,  Italian...     4.2   2821  1800
# 4                       Mexican,  American,  Italian     4.4   1094  2000
#
#        State
# 0  Delhi NCR
# 1  Delhi NCR
# 2  Delhi NCR
# 3  Delhi NCR
# 4  Delhi NCR

# %% [markdown]
# 2.1 State-Wise Distribution

# %%
# Forming state-wise dataframe
df_state = df.groupby('State').mean()
df_state.reset_index(level = 0, inplace = True)
df_state
# Out:
#              State    Rating       Votes         Cost
# 0           Bengal  3.990590  108.025281   880.897472
# 1        Delhi NCR  4.196589  268.772890  1516.921005
# 2              Goa  4.153333   27.216667  1480.000000
# 3          Gujarat  4.164675   43.014060   743.233743
# 4        Karnataka  4.029931  100.210010   924.288518
# 5   Madhya Pradesh  3.790686   55.382353  1017.892157
# 6      Maharashtra  4.146591  100.781469  1205.594406
# 7           Punjab  4.094785   47.055215  1033.742331
# 8        Rajasthan  4.090032   40.488746  1145.337621
# 9       Tamil Nadu  4.025258   80.074742   937.113402
# 10       Telangana  4.040917  155.466893  1114.940577
# 11   Uttar Pradesh  4.123871   36.180645  1280.645161

# %%
fig = px.bar(df_state, x = 'State', y = 'Rating')
fig.update_layout(xaxis_title = 'States', yaxis_title = 'Average Rating', 
                  title_text = 'Rating Distribution Across States', 
                  title_x = 0.5)
fig.show()
# Out:
# <div>                            <div id="b0b54dcd-011b-4d93-831f-9236936ada0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0b54dcd-011b-4d93-831f-9236936ada0f")) {                    Plotly.newPlot(                        "b0b54dcd-011b-4d93-831f-9236936ada0f",                        [{"alignmentgroup":"True","hovertemplate":"State=%{x}<br>Rating=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Bengal","Delhi NCR","Goa","Gujarat","Karnataka","Madhya Pradesh","Maharashtra","Punjab","Rajasthan","Tamil Nadu","Telangana","Uttar Pradesh"],"xaxis":"x","y":[3.9905898876404495,4.196588868940754,4.153333333333333,4.164674868189806,4.029931305201178,3.7906862745098038,4.146590909090909,4.09478527607362,4.090032154340836,4.025257731958763,4.040916808149405,4.123870967741936],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3 ...

# %% [markdown]
# The bar graph shows that rating variation is quite small for different states.

# %% [markdown]
# Comparing Ratings with Polar Bar Plot

# %%
labels = df_state['State']
x1 = df_state['Rating']

num_slices = len(x1)
theta = [(i+1.5)*360/num_slices for i in range(num_slices)]
r=x1
width = [360 / num_slices for _ in range(num_slices)]


barpolar_plots = [go.Barpolar(r=[r], theta=[t], width=[w], name=n)
for r, t, w, n in zip(r, theta, width, labels)]

fig = go.Figure(barpolar_plots)

fig.update_layout(polar = dict(
                        radialaxis = dict(range=[3.5, 4.25], showticklabels=True),
                        angularaxis = dict(showticklabels=False, ticks='')
                        ),
                    title_text='Comparison of Ratings Across States', 
                    title_x=0.45,
                    font=dict(
                      family="Courier New, monospace",
                      size=12,
                  )
)
fig.show()
# Out:
# <div>                            <div id="c7f9b480-bb38-455d-9540-245a21dfb911" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7f9b480-bb38-455d-9540-245a21dfb911")) {                    Plotly.newPlot(                        "c7f9b480-bb38-455d-9540-245a21dfb911",                        [{"name":"Bengal","r":[3.9905898876404495],"theta":[45.0],"width":[30.0],"type":"barpolar"},{"name":"Delhi NCR","r":[4.196588868940754],"theta":[75.0],"width":[30.0],"type":"barpolar"},{"name":"Goa","r":[4.153333333333333],"theta":[105.0],"width":[30.0],"type":"barpolar"},{"name":"Gujarat","r":[4.164674868189806],"theta":[135.0],"width":[30.0],"type":"barpolar"},{"name":"Karnataka","r":[4.029931305201178],"theta":[165.0],"width":[30.0],"type":"barpolar"},{"name":"Madhya Pradesh","r":[3.7906862745098038],"theta":[195.0],"width":[30.0],"type":"barpolar"},{"name":"Maharashtra","r":[4.146590909090909],"theta":[225.0],"width":[30.0],"type":"barpolar"},{"name":"Punjab","r":[4.09478527607362],"theta":[255.0],"width":[30.0],"type":"barpolar"},{"name":"Rajasthan","r":[4.090032154340836],"theta":[285.0],"width":[30.0],"type":"barpolar"},{"name":"Tamil Nadu","r":[4.025257731958763],"theta":[315.0],"width":[30.0],"type":"barpolar"},{"name":"Telangana","r":[4.040916808149405],"theta":[345.0],"width":[30.0],"type":"barpolar"},{"name":"Uttar Pradesh","r":[4.123870967741936],"theta":[375.0],"width":[30.0],"type":"barpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666666 ...

# %% [markdown]
# 2.2 City-Wise Distribution

# %%
df_city = df.groupby('City').mean()
df_city.reset_index(level = 0, inplace = True)
df_city
# Out:
#           City    Rating       Votes         Cost
# 0         Agra  4.238667   19.613333  1320.000000
# 1    Ahmedabad  4.202899   50.422705   777.294686
# 2    Bangalore  4.029931  100.210010   924.288518
# 3   Chandigarh  4.137500   53.083333   984.848485
# 4      Chennai  4.025258   80.074742   937.113402
# 5        Delhi  4.176567  304.476839  1526.634877
# 6    Ghaziabad  4.086000  128.800000  1374.000000
# 7          Goa  4.153333   27.216667  1480.000000
# 8      Gurgaon  4.308696  218.353261  1610.326087
# 9    Hyderabad  4.040917  155.466893  1114.940577
# 10      Indore  3.790686   55.382353  1017.892157
# 11      Jaipur  4.092910   43.783582  1149.253731
# 12     Kolkata  3.990590  108.025281   880.897472
# 13     Lucknow  4.016250   51.712500  1243.750000
# 14    Ludhiana  3.912903   21.387097  1241.935484
# 15      Mumbai  4.180330  110.430536  1271.733150
# 16      Nagpur  4.136364   20.151515  1056.060606
# 17       Noida  4.193836  200.753425  1399.315068
# 18        Pune  4.078632   95.957265  1096.723647
# 19       Surat  3.964062   33.500000   709.375000
# 20     Udaipur  4.072093   19.953488  1120.930233
# 21    Vadodara  4.131868   16.000000   612.087912

# %%
fig = px.bar(df_city, x = 'City', y = 'Rating')
fig.update_layout(xaxis_title = 'Cities', yaxis_title = 'Average Rating', 
                  title_text='Rating Distribution Across Cities')
fig.show()
# Out:
# <div>                            <div id="39193983-e124-41a4-80d0-efdb50c0a000" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("39193983-e124-41a4-80d0-efdb50c0a000")) {                    Plotly.newPlot(                        "39193983-e124-41a4-80d0-efdb50c0a000",                        [{"alignmentgroup":"True","hovertemplate":"City=%{x}<br>Rating=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Agra","Ahmedabad","Bangalore","Chandigarh","Chennai","Delhi","Ghaziabad","Goa","Gurgaon","Hyderabad","Indore","Jaipur","Kolkata","Lucknow","Ludhiana","Mumbai","Nagpur","Noida","Pune","Surat","Udaipur","Vadodara"],"xaxis":"x","y":[4.238666666666666,4.202898550724638,4.029931305201178,4.1375,4.025257731958763,4.1765667574931875,4.086,4.153333333333333,4.308695652173912,4.040916808149405,3.7906862745098038,4.092910447761194,3.9905898876404495,4.01625,3.9129032258064513,4.180330123796423,4.136363636363637,4.1938356164383555,4.078632478632478,3.9640625,4.072093023255814,4.131868131868132],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}]," ...

# %% [markdown]
# The bar graph shows that rating variation is small for different cities.

# %% [markdown]
# Comparing Ratings with Polar Bar Plot

# %%
labels = df_city['City']
x1 = df_city['Rating']

num_slices = len(x1)
theta = [(i+1.5)*360/num_slices for i in range(num_slices)]
r=x1
width = [360 / num_slices for _ in range(num_slices)]

barpolar_plots = [go.Barpolar(r=[r], theta=[t], width=[w], name=n)
for r, t, w, n in zip(r, theta, width, labels)]

fig = go.Figure(barpolar_plots)


fig.update_layout(#     template='ggplot2',
                    polar = dict(
                        radialaxis = dict(range=[3.5, 4.33], showticklabels=True),
                        angularaxis = dict(showticklabels=False, ticks='')
                        ),
                    yaxis_title = 'States', xaxis_title = 'Total Restaurants', 
                    title_text='Comparison of Ratings Across Cities', 
                    title_x=0.47,
                    font=dict(
                      family="Courier New, monospace",
                      size=12,
#                       color='rgb(12, 128, 128)'
                  )
)
fig.show()
# Out:
# <div>                            <div id="9a9c966c-dd95-48df-acb0-2e7ab9d0c2d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a9c966c-dd95-48df-acb0-2e7ab9d0c2d2")) {                    Plotly.newPlot(                        "9a9c966c-dd95-48df-acb0-2e7ab9d0c2d2",                        [{"name":"Agra","r":[4.238666666666666],"theta":[24.545454545454547],"width":[16.363636363636363],"type":"barpolar"},{"name":"Ahmedabad","r":[4.202898550724638],"theta":[40.90909090909091],"width":[16.363636363636363],"type":"barpolar"},{"name":"Bangalore","r":[4.029931305201178],"theta":[57.27272727272727],"width":[16.363636363636363],"type":"barpolar"},{"name":"Chandigarh","r":[4.1375],"theta":[73.63636363636364],"width":[16.363636363636363],"type":"barpolar"},{"name":"Chennai","r":[4.025257731958763],"theta":[90.0],"width":[16.363636363636363],"type":"barpolar"},{"name":"Delhi","r":[4.1765667574931875],"theta":[106.36363636363636],"width":[16.363636363636363],"type":"barpolar"},{"name":"Ghaziabad","r":[4.086],"theta":[122.72727272727273],"width":[16.363636363636363],"type":"barpolar"},{"name":"Goa","r":[4.153333333333333],"theta":[139.0909090909091],"width":[16.363636363636363],"type":"barpolar"},{"name":"Gurgaon","r":[4.308695652173912],"theta":[155.45454545454547],"width":[16.363636363636363],"type":"barpolar"},{"name":"Hyderabad","r":[4.040916808149405],"theta":[171.8181818181818],"width":[16.363636363636363],"type":"barpolar"},{"name":"Indore","r":[3.7906862745098038],"theta":[188.1818181818182],"width":[16.363636363636363],"type":"barpolar"},{"name":"Jaipur","r":[4.092910447761194],"theta":[204.54545454545453],"width":[16.363636363636363],"type":"barpolar"},{"name":"Kolkata","r":[3.9905898876404495],"theta":[220.9090909090909],"width":[16.363636363636363],"type":"barpolar"},{"name":"Lucknow","r":[4.01625],"theta":[237.27272727272728],"width":[16.363636363636363],"type":"barpolar"},{"name":"Ludhiana","r":[3.9129032258064513],"theta":[253.63636363636363],"width":[16.363636363636363],"type":"barpolar"},{"name":"Mumbai","r":[4.180330123796423],"theta":[270.0],"width":[16.363636363636363],"type":"barpolar"},{"name":"Nagpur","r":[4.136363636363637],"theta":[286.3636363636364],"width":[16.363636363636363],"type":"barpolar"},{"name":"Noida","r":[4.1938356164383555],"theta":[302.72727272727275],"width":[16.363636363636363],"type":"barpolar"},{"name":"Pune","r":[4.078632478632478],"theta":[319.09090909090907],"width":[16.363636363636363],"type":"barpolar"},{"name":"Surat","r":[3.9640625],"theta":[335.45454545454544],"width":[16.363636363636363],"type":"barpolar"},{"name":"Udaipur","r":[4.072093023255814],"theta":[351.8181818181818],"width":[16.363636363636363],"type":"barpolar"},{"name":"Vadodara","r":[4.131868131868132],"theta":[368.1818181818182],"width":[16.363636363636363],"type":"barpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"o ...

# %% [markdown]
# The bar graph shows that rating variation is small for different cities.

# %% [markdown]
# Inference 3: How is cost distributed across India?

# %% [markdown]
# 3.1 State-wise Distribution

# %%
df_state
# Out:
#              State    Rating       Votes         Cost
# 0           Bengal  3.990590  108.025281   880.897472
# 1        Delhi NCR  4.196589  268.772890  1516.921005
# 2              Goa  4.153333   27.216667  1480.000000
# 3          Gujarat  4.164675   43.014060   743.233743
# 4        Karnataka  4.029931  100.210010   924.288518
# 5   Madhya Pradesh  3.790686   55.382353  1017.892157
# 6      Maharashtra  4.146591  100.781469  1205.594406
# 7           Punjab  4.094785   47.055215  1033.742331
# 8        Rajasthan  4.090032   40.488746  1145.337621
# 9       Tamil Nadu  4.025258   80.074742   937.113402
# 10       Telangana  4.040917  155.466893  1114.940577
# 11   Uttar Pradesh  4.123871   36.180645  1280.645161

# %% [markdown]
# Cost distribution across states

# %%
df_state.sort_values(by = ['Cost'], inplace = True)

fig = px.bar(df_state, x = 'Cost', y='State', color = 'Cost', orientation = 'h',
            labels = {
                'Cost': 'Average' +'<br>'+ 'Cost'
            })
fig.update_layout(yaxis_title = 'States', xaxis_title = 'Average Cost', 
                  title_text='Average Cost Distribution Across States', 
                  title_x=0.5)
fig.show()
# Out:
# <div>                            <div id="6971fae5-8b31-45e6-a60a-e14acab7f3ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6971fae5-8b31-45e6-a60a-e14acab7f3ae")) {                    Plotly.newPlot(                        "6971fae5-8b31-45e6-a60a-e14acab7f3ae",                        [{"alignmentgroup":"True","hovertemplate":"Average<br>Cost=%{marker.color}<br>State=%{y}<extra></extra>","legendgroup":"","marker":{"color":[743.2337434094903,880.8974719101124,924.288518155054,937.1134020618557,1017.8921568627451,1033.7423312883436,1114.9405772495757,1145.3376205787781,1205.5944055944055,1280.6451612903227,1480.0,1516.9210053859965],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[743.2337434094903,880.8974719101124,924.288518155054,937.1134020618557,1017.8921568627451,1033.7423312883436,1114.9405772495757,1145.3376205787781,1205.5944055944055,1280.6451612903227,1480.0,1516.9210053859965],"xaxis":"x","y":["Gujarat","Bengal","Karnataka","Tamil Nadu","Madhya Pradesh","Punjab","Telangana","Rajasthan","Maharashtra","Uttar Pradesh","Goa","Delhi NCR"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidit ...

# %% [markdown]
# 3.2 City-wise Distribution

# %%
df_city
# Out:
#           City    Rating       Votes         Cost
# 0         Agra  4.238667   19.613333  1320.000000
# 1    Ahmedabad  4.202899   50.422705   777.294686
# 2    Bangalore  4.029931  100.210010   924.288518
# 3   Chandigarh  4.137500   53.083333   984.848485
# 4      Chennai  4.025258   80.074742   937.113402
# 5        Delhi  4.176567  304.476839  1526.634877
# 6    Ghaziabad  4.086000  128.800000  1374.000000
# 7          Goa  4.153333   27.216667  1480.000000
# 8      Gurgaon  4.308696  218.353261  1610.326087
# 9    Hyderabad  4.040917  155.466893  1114.940577
# 10      Indore  3.790686   55.382353  1017.892157
# 11      Jaipur  4.092910   43.783582  1149.253731
# 12     Kolkata  3.990590  108.025281   880.897472
# 13     Lucknow  4.016250   51.712500  1243.750000
# 14    Ludhiana  3.912903   21.387097  1241.935484
# 15      Mumbai  4.180330  110.430536  1271.733150
# 16      Nagpur  4.136364   20.151515  1056.060606
# 17       Noida  4.193836  200.753425  1399.315068
# 18        Pune  4.078632   95.957265  1096.723647
# 19       Surat  3.964062   33.500000   709.375000
# 20     Udaipur  4.072093   19.953488  1120.930233
# 21    Vadodara  4.131868   16.000000   612.087912

# %% [markdown]
# Cost distribution across cities

# %%
df_city.sort_values(by = ['Cost'], inplace = True)
df_city
fig = px.bar(df_city, x = 'Cost', y = 'City', color = 'Cost', orientation = 'h',
            labels = {
                'Cost': 'Average' +'<br>'+ 'Cost'
            })
fig.update_layout(yaxis_title = 'States', xaxis_title = 'Average Cost', 
                  title_text = 'Average Cost Distribution Across Cities', 
                  title_x = 0.5)

fig.show()
# Out:
# <div>                            <div id="0a548aff-9015-49e2-9c9f-3c7a670f0d60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0a548aff-9015-49e2-9c9f-3c7a670f0d60")) {                    Plotly.newPlot(                        "0a548aff-9015-49e2-9c9f-3c7a670f0d60",                        [{"alignmentgroup":"True","hovertemplate":"Average<br>Cost=%{marker.color}<br>City=%{y}<extra></extra>","legendgroup":"","marker":{"color":[612.0879120879121,709.375,777.2946859903382,880.8974719101124,924.288518155054,937.1134020618557,984.8484848484849,1017.8921568627451,1056.060606060606,1096.7236467236467,1114.9405772495757,1120.9302325581396,1149.2537313432836,1241.9354838709678,1243.75,1271.7331499312243,1320.0,1374.0,1399.3150684931506,1480.0,1526.6348773841962,1610.3260869565217],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[612.0879120879121,709.375,777.2946859903382,880.8974719101124,924.288518155054,937.1134020618557,984.8484848484849,1017.8921568627451,1056.060606060606,1096.7236467236467,1114.9405772495757,1120.9302325581396,1149.2537313432836,1241.9354838709678,1243.75,1271.7331499312243,1320.0,1374.0,1399.3150684931506,1480.0,1526.6348773841962,1610.3260869565217],"xaxis":"x","y":["Vadodara","Surat","Ahmedabad","Kolkata","Bangalore","Chennai","Chandigarh","Indore","Nagpur","Pune","Hyderabad","Udaipur","Jaipur","Ludhiana","Lucknow","Mumbai","Agra","Ghaziabad","Noida","Goa","Delhi","Gurgaon"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222, ...

# %% [markdown]
# Inference 4: How are votes distributed across India?

# %% [markdown]
# 4.1 State-wise Distribution

# %%
df_state
# Out:
#              State    Rating       Votes         Cost
# 3          Gujarat  4.164675   43.014060   743.233743
# 0           Bengal  3.990590  108.025281   880.897472
# 4        Karnataka  4.029931  100.210010   924.288518
# 9       Tamil Nadu  4.025258   80.074742   937.113402
# 5   Madhya Pradesh  3.790686   55.382353  1017.892157
# 7           Punjab  4.094785   47.055215  1033.742331
# 10       Telangana  4.040917  155.466893  1114.940577
# 8        Rajasthan  4.090032   40.488746  1145.337621
# 6      Maharashtra  4.146591  100.781469  1205.594406
# 11   Uttar Pradesh  4.123871   36.180645  1280.645161
# 2              Goa  4.153333   27.216667  1480.000000
# 1        Delhi NCR  4.196589  268.772890  1516.921005

# %% [markdown]
# Cost distribution across states

# %%
df_state.sort_values(by=['Votes'], inplace = True)

fig = px.bar(df_state, x = 'Votes', y = 'State', color = 'Votes', orientation = 'h',
            labels = {
                'Votes': 'Average' +'<br>'+ 'Votes'
            })
fig.update_layout(yaxis_title = 'States', xaxis_title = 'Average Votes', 
                  title_text = 'Votes Distribution Across States', 
                  title_x=0.5)
                  
fig.show()
# Out:
# <div>                            <div id="9bfadec1-98d7-425c-8c9e-6f99797bbc61" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9bfadec1-98d7-425c-8c9e-6f99797bbc61")) {                    Plotly.newPlot(                        "9bfadec1-98d7-425c-8c9e-6f99797bbc61",                        [{"alignmentgroup":"True","hovertemplate":"Average<br>Votes=%{marker.color}<br>State=%{y}<extra></extra>","legendgroup":"","marker":{"color":[27.216666666666665,36.18064516129032,40.48874598070739,43.01405975395431,47.05521472392638,55.38235294117647,80.07474226804123,100.21000981354268,100.78146853146853,108.0252808988764,155.46689303904924,268.77289048473966],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[27.216666666666665,36.18064516129032,40.48874598070739,43.01405975395431,47.05521472392638,55.38235294117647,80.07474226804123,100.21000981354268,100.78146853146853,108.0252808988764,155.46689303904924,268.77289048473966],"xaxis":"x","y":["Goa","Uttar Pradesh","Rajasthan","Gujarat","Punjab","Madhya Pradesh","Tamil Nadu","Karnataka","Maharashtra","Bengal","Telangana","Delhi NCR"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overla ...

# %% [markdown]
# 4.2 City-wise Distribution

# %% [markdown]
# Votes distribuion across cities

# %%
df_city.sort_values(by=['Votes'], inplace=True)

fig = px.bar(df_city, x = 'Votes', y='City', color = 'Votes', orientation = 'h',
            labels = {
                'Votes': 'Average' +'<br>'+ 'Votes'
            })
fig.update_layout(yaxis_title = 'Cities', xaxis_title = 'Average Votes', 
                  title_text='Votes Distribution Across Cities', 
                  title_x=0.5)
                
fig.show()
# Out:
# <div>                            <div id="5ebe4700-ea68-45a4-aedb-f6f30ddb869b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ebe4700-ea68-45a4-aedb-f6f30ddb869b")) {                    Plotly.newPlot(                        "5ebe4700-ea68-45a4-aedb-f6f30ddb869b",                        [{"alignmentgroup":"True","hovertemplate":"Average<br>Votes=%{marker.color}<br>City=%{y}<extra></extra>","legendgroup":"","marker":{"color":[16.0,19.613333333333333,19.953488372093023,20.151515151515152,21.387096774193548,27.216666666666665,33.5,43.78358208955224,50.42270531400966,51.7125,53.083333333333336,55.38235294117647,80.07474226804123,95.95726495726495,100.21000981354268,108.0252808988764,110.43053645116919,128.8,155.46689303904924,200.75342465753425,218.35326086956522,304.4768392370572],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[16.0,19.613333333333333,19.953488372093023,20.151515151515152,21.387096774193548,27.216666666666665,33.5,43.78358208955224,50.42270531400966,51.7125,53.083333333333336,55.38235294117647,80.07474226804123,95.95726495726495,100.21000981354268,108.0252808988764,110.43053645116919,128.8,155.46689303904924,200.75342465753425,218.35326086956522,304.4768392370572],"xaxis":"x","y":["Vadodara","Agra","Udaipur","Nagpur","Ludhiana","Goa","Surat","Jaipur","Ahmedabad","Lucknow","Chandigarh","Indore","Chennai","Pune","Bangalore","Kolkata","Mumbai","Ghaziabad","Hyderabad","Noida","Gurgaon","Delhi"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22 ...

# %% [markdown]
# Inference 5: How is the overall performance of restaurants across different states?

# %% [markdown]
# 5.1 Adding Attributes to State Dataframe

# %%
rest_states
# Out:
# Maharashtra       1144
# Delhi NCR         1114
# Karnataka         1019
# Bengal             712
# Telangana          589
# Gujarat            569
# Tamil Nadu         388
# Punjab             326
# Rajasthan          311
# Madhya Pradesh     204
# Uttar Pradesh      155
# Goa                 60
# Name: State, dtype: int64

# %% [markdown]
# Extracting total restaurants in each state and forming its dataframe

# %%
a = rest_states.index
b = rest_states
df_state_restnts = pd.DataFrame(list(zip(a,b)))
df_state_restnts.columns = ['State', 'Total Restaurants']
df_state_restnts = df_state_restnts.set_index('State')
display(df_state_restnts)
# Out:
#                 Total Restaurants
# State
# Maharashtra                  1144
# Delhi NCR                    1114
# Karnataka                    1019
# Bengal                        712
# Telangana                     589
# Gujarat                       569
# Tamil Nadu                    388
# Punjab                        326
# Rajasthan                     311
# Madhya Pradesh                204
# Uttar Pradesh                 155
# Goa                            60

# %%
df_state
# Out:
#              State    Rating       Votes         Cost
# 2              Goa  4.153333   27.216667  1480.000000
# 11   Uttar Pradesh  4.123871   36.180645  1280.645161
# 8        Rajasthan  4.090032   40.488746  1145.337621
# 3          Gujarat  4.164675   43.014060   743.233743
# 7           Punjab  4.094785   47.055215  1033.742331
# 5   Madhya Pradesh  3.790686   55.382353  1017.892157
# 9       Tamil Nadu  4.025258   80.074742   937.113402
# 4        Karnataka  4.029931  100.210010   924.288518
# 6      Maharashtra  4.146591  100.781469  1205.594406
# 0           Bengal  3.990590  108.025281   880.897472
# 10       Telangana  4.040917  155.466893  1114.940577
# 1        Delhi NCR  4.196589  268.772890  1516.921005

# %%
# Taking State column in dataframe as index
df_state = df_state.set_index('State')
df_state
# Out:
#                   Rating       Votes         Cost
# State
# Goa             4.153333   27.216667  1480.000000
# Uttar Pradesh   4.123871   36.180645  1280.645161
# Rajasthan       4.090032   40.488746  1145.337621
# Gujarat         4.164675   43.014060   743.233743
# Punjab          4.094785   47.055215  1033.742331
# Madhya Pradesh  3.790686   55.382353  1017.892157
# Tamil Nadu      4.025258   80.074742   937.113402
# Karnataka       4.029931  100.210010   924.288518
# Maharashtra     4.146591  100.781469  1205.594406
# Bengal          3.990590  108.025281   880.897472
# Telangana       4.040917  155.466893  1114.940577
# Delhi NCR       4.196589  268.772890  1516.921005

# %%
# Matching indices of df_state_restnts with df_state 
df_state_restnts.reindex(df_state.index)
# Out:
#                 Total Restaurants
# State
# Goa                            60
# Uttar Pradesh                 155
# Rajasthan                     311
# Gujarat                       569
# Punjab                        326
# Madhya Pradesh                204
# Tamil Nadu                    388
# Karnataka                    1019
# Maharashtra                  1144
# Bengal                        712
# Telangana                     589
# Delhi NCR                    1114

# %%
# Adding total restaurants column to state dataframe  
df_state['Total Restaurants'] = df_state_restnts['Total Restaurants']
df_state
# Out:
#                   Rating       Votes         Cost  Total Restaurants
# State
# Goa             4.153333   27.216667  1480.000000                 60
# Uttar Pradesh   4.123871   36.180645  1280.645161                155
# Rajasthan       4.090032   40.488746  1145.337621                311
# Gujarat         4.164675   43.014060   743.233743                569
# Punjab          4.094785   47.055215  1033.742331                326
# Madhya Pradesh  3.790686   55.382353  1017.892157                204
# Tamil Nadu      4.025258   80.074742   937.113402                388
# Karnataka       4.029931  100.210010   924.288518               1019
# Maharashtra     4.146591  100.781469  1205.594406               1144
# Bengal          3.990590  108.025281   880.897472                712
# Telangana       4.040917  155.466893  1114.940577                589
# Delhi NCR       4.196589  268.772890  1516.921005               1114

# %%
# Normalizing columns with integer values
df_state_normalized = df_state.copy()
columns = ['Rating', 'Votes', 'Cost', 'Total Restaurants']

# apply normalization techniques
for column in columns:
    df_state_normalized[column] = (df_state_normalized[column] / df_state_normalized[column].abs().max())

# view normalized data
df_state_normalized.reset_index(level=0, inplace=True)
display(df_state_normalized)
# Out:
#              State    Rating     Votes      Cost  Total Restaurants
# 0              Goa  0.989693  0.101263  0.975661           0.052448
# 1    Uttar Pradesh  0.982672  0.134614  0.844240           0.135490
# 2        Rajasthan  0.974609  0.150643  0.755041           0.271853
# 3          Gujarat  0.992395  0.160039  0.489962           0.497378
# 4           Punjab  0.975741  0.175074  0.681474           0.284965
# 5   Madhya Pradesh  0.903278  0.206056  0.671025           0.178322
# 6       Tamil Nadu  0.959174  0.297927  0.617773           0.339161
# 7        Karnataka  0.960287  0.372843  0.609319           0.890734
# 8      Maharashtra  0.988086  0.374969  0.794764           1.000000
# 9           Bengal  0.950913  0.401920  0.580714           0.622378
# 10       Telangana  0.962905  0.578432  0.735002           0.514860
# 11       Delhi NCR  1.000000  1.000000  1.000000           0.973776

# %% [markdown]
# 5.2 Comparing Attributes of all States

# %%
# Comparing attributes of all states using polar scatter plots

fig = make_subplots(rows=6, cols=2, specs=[[{'type': 'polar'}]*2]*6, column_widths=[0.45, 0.45])

for index, state in enumerate(df_state_normalized['State']):
    if index % 2 == 0:
        row = int((index+2)/2)
        col = 1
    else: 
        row = int((index+1)/2) 
        col = 2
      
    fig.add_trace(go.Scatterpolar(
          name = df_state_normalized['State'][index],
          r = [df_state_normalized['Rating'][index], df_state_normalized['Votes'][index], df_state_normalized['Cost'][index], df_state_normalized['Total Restaurants'][index]],
          theta = ['Rating', 'Votes', 'Cost', 'Total Restaurants'],
          fill = 'toself'    
        ), row, col)

fig.update_layout(height = 2000, width = 900, title_text = "Comparison of Restaurants in Different States of India", title_x=0.5, title_font_color = '#4B0082')
fig.show()
# Out:
# <div>                            <div id="6e4a2564-04d1-42cc-b29e-07395970369a" class="plotly-graph-div" style="height:2000px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e4a2564-04d1-42cc-b29e-07395970369a")) {                    Plotly.newPlot(                        "6e4a2564-04d1-42cc-b29e-07395970369a",                        [{"fill":"toself","name":"Goa","r":[0.9896926916221034,0.10126269289131289,0.9756605615883066,0.05244755244755245],"theta":["Rating","Votes","Cost","Total Restaurants"],"type":"scatterpolar","subplot":"polar"},{"fill":"toself","name":"Uttar Pradesh","r":[0.9826721407624633,0.13461419079892128,0.8442398494999079,0.1354895104895105],"theta":["Rating","Votes","Cost","Total Restaurants"],"type":"scatterpolar","subplot":"polar2"},{"fill":"toself","name":"Rajasthan","r":[0.9746087315370462,0.1506429681493724,0.7550410446635848,0.2718531468531469],"theta":["Rating","Votes","Cost","Total Restaurants"],"type":"scatterpolar","subplot":"polar3"},{"fill":"toself","name":"Gujarat","r":[0.9923952520135708,0.16003868424519008,0.48996206181505586,0.4973776223776224],"theta":["Rating","Votes","Cost","Total Restaurants"],"type":"scatterpolar","subplot":"polar4"},{"fill":"toself","name":"Punjab","r":[0.9757413470686658,0.1750742593088944,0.6814740699205342,0.28496503496503495],"theta":["Rating","Votes","Cost","Total Restaurants"],"type":"scatterpolar","subplot":"polar5"},{"fill":"toself","name":"Madhya Pradesh","r":[0.903277970011534,0.20605632078924627,0.6710251577034044,0.17832167832167833],"theta":["Rating","Votes","Cost","Total Restaurants"],"type":"scatterpolar","subplot":"polar6"},{"fill":"toself","name":"Tamil Nadu","r":[0.9591737140966976,0.2979271537528362,0.6177733703564856,0.33916083916083917],"theta":["Rating","Votes","Cost","Total Restaurants"],"type":"scatterpolar","subplot":"polar7"},{"fill":"toself","name":"Karnataka","r":[0.9602873741163875,0.37284269865465614,0.6093188207383674,0.8907342657342657],"theta":["Rating","Votes","Cost","Total Restaurants"],"type":"scatterpolar","subplot":"polar8"},{"fill":"toself","name":"Maharashtra","r":[0.9880860476421973,0.3749688755800715,0.7947641316283502,1.0],"theta":["Rating","Votes","Cost","Total Restaurants"],"type":"scatterpolar","subplot":"polar9"},{"fill":"toself","name":"Bengal","r":[0.9509127561136814,0.4019203004590593,0.5807141365848242,0.6223776223776224],"theta":["Rating","Votes","Cost","Total Restaurants"],"type":"scatterpolar","subplot":"polar10"},{"fill":"toself","name":"Telangana","r":[0.9629050961023395,0.5784321951468402,0.7350023984708863,0.5148601398601399],"theta":["Rating","Votes","Cost","Total Restaurants"],"type":"scatterpolar","subplot":"polar11"},{"fill":"toself","name":"Delhi NCR","r":[1.0,1.0,1.0,0.9737762237762237],"theta":["Rating","Votes","Cost","Total Restaurants"],"type":"scatterpolar","subplot":"polar12"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"tic ...

# %% [markdown]
# Inference 6: What are top cuisines in India?

# %% [markdown]
# 6.1 Forming Cuisines Dataframe

# %%
df.head()
# Out:
#                              Name  \
# 0                           Local
# 1                   The G.T. ROAD
# 2                         Tamasha
# 3               The Junkyard Cafe
# 4  Chili's American Grill and Bar
#
#                                        Location        Locality   City  \
# 0  Scindia House,Connaught Place, Central Delhi   Central Delhi  Delhi
# 1        M-Block,Connaught Place, Central Delhi   Central Delhi  Delhi
# 2                Connaught Place, Central Delhi   Central Delhi  Delhi
# 3                Connaught Place, Central Delhi   Central Delhi  Delhi
# 4        M-Block,Connaught Place, Central Delhi   Central Delhi  Delhi
#
#                                              Cuisine  Rating  Votes  Cost  \
# 0           North Indian,  Finger Food,  Continental     4.1   2415  2000
# 1                                       North Indian     4.3   2363  1500
# 2  Finger Food,  North Indian,  Italian,  Contine...     4.2   5016  2000
# 3  North Indian,  Mediterranean,  Asian,  Italian...     4.2   2821  1800
# 4                       Mexican,  American,  Italian     4.4   1094  2000
#
#        State
# 0  Delhi NCR
# 1  Delhi NCR
# 2  Delhi NCR
# 3  Delhi NCR
# 4  Delhi NCR

# %%
cuisines = df['Cuisine'].str.split(',').explode().unique().tolist()

# %%
# Forming cuisine dataframe
data = []
df_filtered = pd.DataFrame()
columns = ['Cuisine', 'Total Restaurants', 'Rating']
df_cuisine = pd.DataFrame(columns = columns)

for cuisine in cuisines:
    
    df['Cuisine Verification'] = df['Cuisine'].str.contains(cuisine, case=False, na=False).astype(int)
    df_filtered = df[df['Cuisine Verification'] == 1]
    total_restnt = len(df_filtered.index)
    df = df.drop(['Cuisine Verification'], axis=1)
    
    avg_rating = df_filtered['Rating'].sum()/total_restnt
    df_cuisine = df_cuisine.append({'Cuisine': cuisine, 'Total Restaurants': total_restnt, 'Rating':avg_rating, }, ignore_index=True)

# %%
df_cuisine.head()
# Out:
#           Cuisine Total Restaurants    Rating
# 0    North Indian              3296  4.070995
# 1     Finger Food               155  4.083871
# 2     Continental              1391  4.148311
# 3     Finger Food               312  4.087821
# 4    North Indian              1068  4.108989

# %%
df_cuisine.shape
# Out:
# (170, 3)

# %% [markdown]
# 6.2 Identifying Top Cuisines

# %%
fig = go.Figure(data = [
    go.Bar(name = 'Total Restaurants', x = df_cuisine['Cuisine'], y = df_cuisine['Total Restaurants'])
])
fig.update_layout(xaxis_title = 'Cuisines', yaxis_title = 'Total Restaurants', 
                  title_text='Cuisine Distribution Across Restaurants', 
                  title_x=0.5)
fig.show()
# Out:
# <div>                            <div id="53398e24-3d57-4dbd-86ae-b521af4a2f3a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53398e24-3d57-4dbd-86ae-b521af4a2f3a")) {                    Plotly.newPlot(                        "53398e24-3d57-4dbd-86ae-b521af4a2f3a",                        [{"name":"Total Restaurants","x":["North Indian","  Finger Food","  Continental","Finger Food","  North Indian","  Italian","  Asian","  Mediterranean","  Oriental ","Mexican","  American","Multi-Cuisine","  Chinese","  Seafood","Rajasthani","  Fusion","South Indian","  Mughlai","Modern Indian","  Modern Indian","  Japanese","World Cuisine","  Multi-Cuisine","  Fast Food","  Mexican","  European","  Tex Mex","  Thai","Asian","  Korean","Italian","Continental","Chinese","  Barbecue","  Andhra","Mughlai","  Biryani","  Street Food","  Coffee","  South Indian","Biryani","  Hyderabadi","Street Food","  Tea","Gujarati","  Rajasthani","Desserts","  Ice Cream","Fast Food","  Shakes","  Bakery and Confectionary","  Pizza","  Sushi","  Indian Cuisine","European","Sizzlers","  Gujarati","  Spanish","American","  Waffle","  Lebanese","  Kerala","Bakery and Confectionary","  Desserts","Seafood","  Goan","Pizza","  Kashmiri","  French","  Tibetan","Japanese","Health Food","Thai","  Indonesian","  Mithai","  South American","Shakes","Arabian","  Deli","Mediterranean","  Middle Eastern","  Doughnuts","  Burger","Nepalese","Korean","  Malaysian","  North Eastern","Naga","  Health Food","  Turkish","  Juice","Oriental ","  Bengali","Indian Cuisine","  Bihari","  Chettinad","Tibetan","  Nepalese","Coffee","  Singaporean","Turkish","  Iranian","Bengali","Malaysian","Singaporean","Mithai","  Vietnamese","Burger","Lebanese","  Lucknowi","Vietnamese","African","  Portuguese","Goan","Tea","  Greek","Spanish","  Moroccan","Juice","  Mangalorean","  Coastal","  Sizzlers","  Awadhi","  Malvani","  British","  Maharashtrian","  Parsi","  Burmese","Parsi","  Arabian","Ice Cream","  Assamese","  Cantonese","Sindhi","  Drinks","Maharashtrian","Waffle","  Yogurt","  Konkani","Kerala","Barbecue","French","  Chaat","  Persian","Coastal","Awadhi","Drinks","Mangalorean","  Pakistani","Andhra","Bihari","Assamese","  African","Hyderabadi","Doughnuts","  Contemporary Continental","Fusion","  Afghani","Burmese","Middle Eastern","Chettinad","Persian","Afghani","  Western","British","Cantonese","  World Cuisine","  North West Frontier","Sushi","  German"],"y":[3296,155,1391,312,1068,1093,379,107,298,332,173,689,2007,558,38,14,583,425,77,45,106,8,30,1043,223,169,43,246,497,17,1550,1651,2386,102,68,454,172,91,172,386,189,24,161,126,57,28,806,185,1641,263,151,200,46,28,208,26,41,7,208,96,35,45,236,446,588,36,294,3,7,85,129,115,374,5,21,2,305,51,1,117,3,36,38,4,21,15,2,2,58,7,13,308,29,31,1,17,97,2,200,3,10,5,65,16,4,113,7,45,52,3,8,2,3,45,148,6,8,3,32,7,11,20,11,18,1,27,3,7,7,34,232,4,5,1,86,40,104,2,5,56,132,10,18,1,12,12,91,9,1,86,2,5,1,29,38,1,20,3,8,6,18,2,4,2,2,6,3,1,47,1],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b ...

# %% [markdown]
# Many cuisines are served in very few restaurants.

# %% [markdown]
# Filtering cuisines

# %%
# Taking cuisines that are atleast served in over 300 restaurants 
df_cuisine = df_cuisine[df_cuisine['Total Restaurants'] > 300]
df_cuisine.shape
# Out:
# (26, 3)

# %%
fig = go.Figure(data = [
    go.Bar(name = 'Total Restaurants', x = df_cuisine['Cuisine'], y = df_cuisine['Total Restaurants'])
])

fig.update_layout(xaxis_title = 'Cuisines', yaxis_title = 'Total Restaurants', 
                  title_text = 'Distribution of Top Cuisines Across Restaurants', 
                  title_x = 0.5)
fig.show()
# Out:
# <div>                            <div id="4cbe8bed-b73d-4bc0-bec4-6ab8533d07bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4cbe8bed-b73d-4bc0-bec4-6ab8533d07bd")) {                    Plotly.newPlot(                        "4cbe8bed-b73d-4bc0-bec4-6ab8533d07bd",                        [{"name":"Total Restaurants","x":["North Indian","  Continental","Finger Food","  North Indian","  Italian","  Asian","Mexican","Multi-Cuisine","  Chinese","  Seafood","South Indian","  Mughlai","  Fast Food","Asian","Italian","Continental","Chinese","Mughlai","  South Indian","Desserts","Fast Food","  Desserts","Seafood","Thai","Shakes","Oriental "],"y":[3296,1391,312,1068,1093,379,332,689,2007,558,583,425,1043,497,1550,1651,2386,454,386,806,1641,446,588,374,305,308],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"sc ...

# %% [markdown]
# Cuisines dataframe consists of duplicate values.
# Multi-Cuisine is not a valid category.

# %%
# Printing some duplicate categories
df_cuisine.Cuisine[0], df_cuisine.Cuisine[13], df_cuisine.Cuisine[0], df_cuisine.Cuisine[64]
# Out:
# ('North Indian', '  Seafood', 'North Indian', 'Seafood')

# %% [markdown]
# Double spacing before text is resulting in dupicates.

# %%
#  Reseting index and removing double space 
df_cuisine = df_cuisine.reset_index(drop = True)   
df_cuisine.Cuisine = df_cuisine.Cuisine.str.replace('  ', '')

# Verifying double space removal
df_cuisine.Cuisine[5], df_cuisine.Cuisine[13], df_cuisine.Cuisine[0], df_cuisine.Cuisine[3]
# Out:
# ('Asian', 'Asian', 'North Indian', 'North Indian')

# %%
#  Identifying with duplicate values
duplicate_cuisine = df_cuisine.duplicated(subset = ['Cuisine'])

# %%
duplicate_cuisines = []
duplicate_cuisines = df_cuisine.loc[duplicate_cuisine]['Cuisine']
duplicate_cuisines
# Out:
# 3     North Indian
# 13           Asian
# 14         Italian
# 15     Continental
# 16         Chinese
# 17         Mughlai
# 18    South Indian
# 20       Fast Food
# 21        Desserts
# 22         Seafood
# Name: Cuisine, dtype: object

# %%
duplicate_indices = []

# Identifying indices dulplicate cuisines 
duplicate_bool = []
count = 0
for index, cuisine in enumerate(duplicate_cuisines):
    duplicate_bool = df_cuisine['Cuisine'].str.find(cuisine)

    for index, value in enumerate(duplicate_bool):
        if value == 0:
            duplicate_indices.append(index)
duplicate_indices
# Out:
# [0, 3, 5, 13, 4, 14, 1, 15, 8, 16, 11, 17, 10, 18, 12, 20, 19, 21, 9, 22]

# %%
# Removing duplicate indices and updating attributes
i = 0
for index in duplicate_indices:
    
    if (i) % 2 == 0:
        count = 0
        # Updating attributes in first duplicate index (or Original Index)
        total_restnt_1 = (df_cuisine['Total Restaurants'][index])
        avg_rating_1 = df_cuisine['Rating'][index]
    
    else:
        count = 2
        total_restnt_2 = (df_cuisine['Total Restaurants'][index])
        avg_rating_2 = df_cuisine['Rating'][index]
    
    i += 1
    if count == 2:
        df_cuisine['Total Restaurants'][(index-1)] = (total_restnt_1 + total_restnt_2)
        df_cuisine['Rating'][(index-1)] = ((total_restnt_1*avg_rating_1) + (total_restnt_2*avg_rating_2))/(total_restnt_1 + total_restnt_2)
        
        # Removing second duplicate index
        df_cuisine = df_cuisine.drop(index)

# %%
df_cuisine = df_cuisine.reset_index(drop = True)
df_cuisine
# Out:
#           Cuisine Total Restaurants    Rating
# 0    North Indian              3296  4.070995
# 1     Continental              1391  4.148311
# 2     Finger Food              4364  4.080293
# 3         Italian              1093  4.163861
# 4           Asian               379  4.221108
# 5         Mexican               332  4.220783
# 6   Multi-Cuisine               689  4.146444
# 7         Chinese              2007  4.056951
# 8         Seafood               558  4.117563
# 9    South Indian               583  4.020583
# 10        Mughlai               425  4.152235
# 11      Fast Food               876  4.237557
# 12       Desserts              2517  4.099841
# 13           Thai               374  4.206952
# 14         Shakes               305  4.099344
# 15      Oriental                308  4.158766

# %%
# Dropping Multi-cuisine
df_cuisine = df_cuisine.drop(index = 6)
df_cuisine = df_cuisine.reset_index(drop = True)
df_cuisine
# Out:
#          Cuisine Total Restaurants    Rating
# 0   North Indian              3296  4.070995
# 1    Continental              1391  4.148311
# 2    Finger Food              4364  4.080293
# 3        Italian              1093  4.163861
# 4          Asian               379  4.221108
# 5        Mexican               332  4.220783
# 6        Chinese              2007  4.056951
# 7        Seafood               558  4.117563
# 8   South Indian               583  4.020583
# 9        Mughlai               425  4.152235
# 10     Fast Food               876  4.237557
# 11      Desserts              2517  4.099841
# 12          Thai               374  4.206952
# 13        Shakes               305  4.099344
# 14     Oriental                308  4.158766

# %%
# Plotting cuisine with total restaurants
fig = go.Figure(data = [
    go.Bar(name = 'Total Restaurants', x = df_cuisine['Cuisine'], y = df_cuisine['Total Restaurants'])
])

fig.update_layout(xaxis_title = 'Cuisines', yaxis_title = 'Total Restaurants', 
                  title_text='Cuisine Distribution Across Restaurants', 
                  title_x=0.5)

fig.show()
# Out:
# <div>                            <div id="a9a1d1a8-ef65-4e6b-b017-23e3e310ebaf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9a1d1a8-ef65-4e6b-b017-23e3e310ebaf")) {                    Plotly.newPlot(                        "a9a1d1a8-ef65-4e6b-b017-23e3e310ebaf",                        [{"name":"Total Restaurants","x":["North Indian","Continental","Finger Food","Italian","Asian","Mexican","Chinese","Seafood","South Indian","Mughlai","Fast Food","Desserts","Thai","Shakes","Oriental "],"y":[3296,1391,4364,1093,379,332,2007,558,583,425,876,2517,374,305,308],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marke ...

# %%
# Plotting rating with cuisines 
fig = go.Figure(data = [
    go.Bar(name='Rating', x=df_cuisine['Cuisine'], y=df_cuisine['Rating']),
])

fig.update_traces(marker_color ='rgb(12, 128, 128)', opacity=1)
fig.update_layout(xaxis_title = 'Cuisines', yaxis_title = 'Average Rating', 
                  title_text = 'Rating Distribution of Top Cuisines', 
                  title_x = 0.5)

fig.show()
# Out:
# <div>                            <div id="23461375-8fdf-4f98-940a-54e5aed18872" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23461375-8fdf-4f98-940a-54e5aed18872")) {                    Plotly.newPlot(                        "23461375-8fdf-4f98-940a-54e5aed18872",                        [{"name":"Rating","x":["North Indian","Continental","Finger Food","Italian","Asian","Mexican","Chinese","Seafood","South Indian","Mughlai","Fast Food","Desserts","Thai","Shakes","Oriental "],"y":[4.070995145631068,4.148310567936735,4.080293308890926,4.163860933211345,4.221108179419525,4.22078313253012,4.05695067264574,4.117562724014337,4.020583190394511,4.152235294117647,4.2375570776255715,4.0998410806515695,4.206951871657754,4.099344262295083,4.158766233766234],"type":"bar","marker":{"color":"rgb(12, 128, 128)"},"opacity":1}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay", ...

# %%
# Analysing with polar plot 
labels = df_cuisine['Cuisine']
x1 = df_cuisine['Rating']
num_slices = len(x1)
theta = [(i+1.5)*360/num_slices for i in range(num_slices)]
r=x1
width = [360 / num_slices for _ in range(num_slices)]

barpolar_plots = [go.Barpolar(r=[r], theta=[t], width=[w], name=n)
for r, t, w, n in zip(r, theta, width, labels)]

fig = go.Figure(barpolar_plots)

fig.update_layout(
                    polar = dict(
                        radialaxis = dict(range=[3.8, 4.25], showticklabels = True),
                        angularaxis = dict(showticklabels = False, ticks = '')
                        ),
                    yaxis_title = 'States', xaxis_title = 'Total Restaurants', 
                    title_text = 'Comparison of Ratings of Different Cuisines', 
                    title_x = 0.46
)
fig.show()
# Out:
# <div>                            <div id="4ad2c7de-dc05-4501-8267-74c7c2ccc465" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ad2c7de-dc05-4501-8267-74c7c2ccc465")) {                    Plotly.newPlot(                        "4ad2c7de-dc05-4501-8267-74c7c2ccc465",                        [{"name":"North Indian","r":[4.070995145631068],"theta":[36.0],"width":[24.0],"type":"barpolar"},{"name":"Continental","r":[4.148310567936735],"theta":[60.0],"width":[24.0],"type":"barpolar"},{"name":"Finger Food","r":[4.080293308890926],"theta":[84.0],"width":[24.0],"type":"barpolar"},{"name":"Italian","r":[4.163860933211345],"theta":[108.0],"width":[24.0],"type":"barpolar"},{"name":"Asian","r":[4.221108179419525],"theta":[132.0],"width":[24.0],"type":"barpolar"},{"name":"Mexican","r":[4.22078313253012],"theta":[156.0],"width":[24.0],"type":"barpolar"},{"name":"Chinese","r":[4.05695067264574],"theta":[180.0],"width":[24.0],"type":"barpolar"},{"name":"Seafood","r":[4.117562724014337],"theta":[204.0],"width":[24.0],"type":"barpolar"},{"name":"South Indian","r":[4.020583190394511],"theta":[228.0],"width":[24.0],"type":"barpolar"},{"name":"Mughlai","r":[4.152235294117647],"theta":[252.0],"width":[24.0],"type":"barpolar"},{"name":"Fast Food","r":[4.2375570776255715],"theta":[276.0],"width":[24.0],"type":"barpolar"},{"name":"Desserts","r":[4.0998410806515695],"theta":[300.0],"width":[24.0],"type":"barpolar"},{"name":"Thai","r":[4.206951871657754],"theta":[324.0],"width":[24.0],"type":"barpolar"},{"name":"Shakes","r":[4.099344262295083],"theta":[348.0],"width":[24.0],"type":"barpolar"},{"name":"Oriental ","r":[4.158766233766234],"theta":[372.0],"width":[24.0],"type":"barpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]} ...

# %% [markdown]
# Inference 7: How are the cuisines distributed among states?

# %%
df.head()
# Out:
#                              Name  \
# 0                           Local
# 1                   The G.T. ROAD
# 2                         Tamasha
# 3               The Junkyard Cafe
# 4  Chili's American Grill and Bar
#
#                                        Location        Locality   City  \
# 0  Scindia House,Connaught Place, Central Delhi   Central Delhi  Delhi
# 1        M-Block,Connaught Place, Central Delhi   Central Delhi  Delhi
# 2                Connaught Place, Central Delhi   Central Delhi  Delhi
# 3                Connaught Place, Central Delhi   Central Delhi  Delhi
# 4        M-Block,Connaught Place, Central Delhi   Central Delhi  Delhi
#
#                                              Cuisine  Rating  Votes  Cost  \
# 0           North Indian,  Finger Food,  Continental     4.1   2415  2000
# 1                                       North Indian     4.3   2363  1500
# 2  Finger Food,  North Indian,  Italian,  Contine...     4.2   5016  2000
# 3  North Indian,  Mediterranean,  Asian,  Italian...     4.2   2821  1800
# 4                       Mexican,  American,  Italian     4.4   1094  2000
#
#        State
# 0  Delhi NCR
# 1  Delhi NCR
# 2  Delhi NCR
# 3  Delhi NCR
# 4  Delhi NCR

# %%
df.tail()
# Out:
#                Name                                           Location  \
# 6588  Shree Rathnam                 Wave Mall,BRS Nagar, West Ludhiana
# 6589    Cafe Delish          Radisson Blu,Rajguru Nagar, West Ludhiana
# 6590    3 K Resorts                           BRS Nagar, West Ludhiana
# 6591      Dovka Bar  Nirvana Hotel Banquets Club,PAU, Central Ludhiana
# 6592    Urban Vibes                         Aggar Nagar, West Ludhiana
#
#                Locality      City  \
# 6588      West Ludhiana  Ludhiana
# 6589      West Ludhiana  Ludhiana
# 6590      West Ludhiana  Ludhiana
# 6591   Central Ludhiana  Ludhiana
# 6592      West Ludhiana  Ludhiana
#
#                                                 Cuisine  Rating  Votes  Cost  \
# 6588                                       South Indian     4.1     20   600
# 6589  Multi-Cuisine,  North Indian,  Continental,  A...     4.4     48  3100
# 6590                                       North Indian     1.0      1  1100
# 6591               North Indian,  Chinese,  Finger Food     4.3      3  1500
# 6592  Multi-Cuisine,  North Indian,  Italian,  Chine...     3.8     12  2000
#
#        State
# 6588  Punjab
# 6589  Punjab
# 6590  Punjab
# 6591  Punjab
# 6592  Punjab

# %% [markdown]
# 7.1 Declaring Function for Obtaining Cuisine Information

# %%
df_state = pd.DataFrame()

def cuisine_info(state):
    state_cuisines_clean =[]

# %%
# Forming state dataframe
    filter = (df['State'] == state)
    df_state = df[filter].copy()
# Out:
#   File "C:\Users\kause\AppData\Local\Temp\ipykernel_3596\4026314972.py", line 2
#     filter = (df['State'] == state)
#     ^
# IndentationError: unexpected indent

# %%
# Filtering cuisines
    state_cuisines = df_state['Cuisine'].str.split(',').explode().unique().tolist()
# Out:
#   File "C:\Users\kause\AppData\Local\Temp\ipykernel_3596\1799673863.py", line 2
#     state_cuisines = df_state['Cuisine'].str.split(',').explode().unique().tolist()
#     ^
# IndentationError: unexpected indent

# %%
df_state = pd.DataFrame()

def cuisine_info(state):
    state_cuisines_clean =[]

# %%
frames = [top_cuisine_uttar, top_cuisine_madhya, top_cuisine_rajasthan, top_cuisine_punjab, top_cuisine_tamil, top_cuisine_gujarat, top_cuisine_telangana, top_cuisine_bengal, top_cuisine_karnataka, top_cuisine_delhi, top_cuisine_maharashtra]
top_cuisine_india = pd.concat(frames)
display(top_cuisine_india)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3596\1791525457.py in <module>
# ----> 1 frames = [top_cuisine_uttar, top_cuisine_madhya, top_cuisine_rajasthan, top_cuisine_punjab, top_cuisine_tamil, top_cuisine_gujarat, top_cuisine_telangana, top_cuisine_bengal, top_cuisine_karnataka, top_cuisine_delhi, top_cuisine_maharashtra]
#       2 top_cuisine_india = pd.concat(frames)
#       3 display(top_cuisine_india)
#
# NameError: name 'top_cuisine_uttar' is not defined

# %%
top_cuisine_india['Country'] = 'India'
fig = px.treemap(top_cuisine_india, 
                 path = ['Country', 'State', 'Cuisine', 'Total Votes'], 
                 values = 'Rating',
                 color = 'Rating'
                )
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3596\4184669624.py in <module>
# ----> 1 top_cuisine_india['Country'] = 'India'
#       2 fig = px.treemap(top_cuisine_india,
#       3                  path = ['Country', 'State', 'Cuisine', 'Total Votes'],
#       4                  values = 'Rating',
#       5                  color = 'Rating'
#
# NameError: name 'top_cuisine_india' is not defined

# %%
df_maharashtra = df[df['State'] == 'Maharashtra']
df_delhi = df[df['State'] == 'Delhi NCR']
df_karnataka = df[df['State'] == 'Karnataka']
df_maharashtra
# Out:
#                            Name  \
# 1114                 Pop Tate's
# 1115              Global Fusion
# 1116                        FOO
# 1117              Kake Da Hotel
# 1118               PizzaExpress
# ...                         ...
# 6460                  Roof Zero
# 6461  Dublin 88 - The Irish Hub
# 6462           Wonders Of World
# 6463                The Habitat
# 6464                     MiCasa
#
#                                                Location          Locality  \
# 1114  Mayfair Sonata Green CHS,Vikhroli West, Centra...   Central Suburbs
# 1115      Times Square Tech Park,Sakinaka, Andheri East      Andheri East
# 1116                     Vikhroli West, Central Suburbs   Central Suburbs
# 1117                                       Powai, Powai             Powai
# 1118             Hiranandani Business Park,Powai, Powai             Powai
# ...                                                 ...               ...
# 6460           Zero Degree,Hingna T Point, South Nagpur      South Nagpur
# 6461                             Vayu Sena, West Nagpur       West Nagpur
# 6462                             Vayu Sena, West Nagpur       West Nagpur
# 6463                       Hingna T Point, South Nagpur      South Nagpur
# 6464                             Gokulpeth, West Nagpur       West Nagpur
#
#         City                               Cuisine  Rating  Votes  Cost  \
# 1114  Mumbai       Chinese,  Italian,  Continental     4.3    333  2000
# 1115  Mumbai        North Indian,  Chinese,  Sushi     4.5    716  2000
# 1116  Mumbai    Asian,  Chinese,  Japanese,  Sushi     4.7     50  1100
# 1117  Mumbai      North Indian,  Chinese,  Mughlai     5.0      1   900
# 1118  Mumbai        European,  Fast Food,  Italian     4.5    590  1400
# ...      ...                                   ...     ...    ...   ...
# 6460  Nagpur  North Indian,  Chinese,  Continental     1.0      1  2200
# 6461  Nagpur            North Indian,  Continental     3.6      5  1300
# 6462  Nagpur  North Indian,  Chinese,  Continental     3.7     36   900
# 6463  Nagpur  North Indian,  Chinese,  Continental     5.0      3  1000
# 6464  Nagpur                North Indian,  Chinese     4.6      2  1200
#
#             State
# 1114  Maharashtra
# 1115  Maharashtra
# 1116  Maharashtra
# 1117  Maharashtra
# 1118  Maharashtra
# ...           ...
# 6460  Maharashtra
# 6461  Maharashtra
# 6462  Maharashtra
# 6463  Maharashtra
# 6464  Maharashtra
#
# [1144 rows x 9 columns]

# %% [markdown]
# 8.2 Defining Function to Return Votes in a Locality

# %%
def total_votes(locality):
    df_x = df[df['Locality'] == locality]
    total_votes = df_x['Votes'].sum()
    return total_votes

# %%
#     Adding attributes to the localities dataframe
df_location = pd.DataFrame()
rating_list = []
cost_list = []
location_rating_list = []
location_cost_list = []
for index, location in enumerate(karnataka_locations_df['Location']):
    df_location = df[df['Locality'] == location]

#     Calculating average rating

    for rating in df_location["Rating"]:
        rating_list.append(rating)
    avg_rating = sum(rating_list)/len(rating_list)
    location_rating_list.append(avg_rating)
    
#     Calculating average cost

    for cost in df_location["Cost"]:
        cost_list.append(cost)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3596\3644706295.py in <module>
#       5 location_rating_list = []
#       6 location_cost_list = []
# ----> 7 for index, location in enumerate(karnataka_locations_df['Location']):
#       8     df_location = df[df['Locality'] == location]
#       9
#
# NameError: name 'karnataka_locations_df' is not defined

# %%
df.tail()
